# %%
 cd /content/drive/MyDrive/deep learning/minimal-BERT
# Out:
# /content/drive/MyDrive/deep learning/minimal-BERT

# %%
from train import *

# %%
train()
# Out:
# Ready to train
# 100%|██████████| 2489/2489 [00:00<00:00, 69784.97it/s]
# Ready to dev
# 100%|██████████| 277/277 [00:00<00:00, 32122.04it/s]
# ...
# Start Pre-training...
#   0%|          | 0/149 [00:00<?, ?it/s]
# [Train Epoch:    1] mlm loss: 6.879, nsp loss: 0.813, loss: 7.692, mlm acc: 27.5738, nsp acc: 48.6541
# [Test Epoch:    1] mlm loss: 0.000, nsp loss: 0.704, loss: 0.704, mlm acc: 38.3800, nsp acc: 48.7365
# Model Saving...
#   1%|          | 1/149 [00:24<59:35, 24.16s/it]
# [Train Epoch:    2] mlm loss: 5.403, nsp loss: 0.719, loss: 6.122, mlm acc: 42.5183, nsp acc: 51.2254
# [Test Epoch:    2] mlm loss: 0.000, nsp loss: 0.715, loss: 0.715, mlm acc: 46.2207, nsp acc: 51.2635
# Model Saving...
#   1%|▏         | 2/149 [00:47<58:23, 23.83s/it]
# [Train Epoch:    3] mlm loss: 4.980, nsp loss: 0.703, loss: 5.683, mlm acc: 47.2680, nsp acc: 49.8996
# [Test Epoch:    3] mlm loss: 0.000, nsp loss: 0.742, loss: 0.742, mlm acc: 47.8452, nsp acc: 45.8484
# Model Saving...
# ...
